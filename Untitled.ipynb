# %%
import pickle

# %%
x=pickle.load(open('../code/minidump.bin', 'rb'))

# %%
import matplotlib.pyplot as plt
plt.plot(x.values[:500])
plt.show()

# %%
x=pickle.load(open('../code/dump.bin', 'rb'))

# %%
sorted(x.items(), key=lambda x: x[1])
# Out:
# [('vendor_id', 7908),
#  ('passenger_count', 10609),
#  ('day_of_week', 14092),
#  ('hour', 27900),
#  ('daily_count', 37686),
#  ('hourly_speed_estim', 44666),
#  ('hourly_count', 44683),
#  ('hourly_speed', 45040),
#  ('euclidean', 48404),
#  ('manhattan', 50356),
#  ('delta_lat', 52818),
#  ('delta_lon', 53725),
#  ('dropoff_longitude', 62023),
#  ('dropoff_latitude', 66996),
#  ('epoch_time', 68303),
#  ('pickup_longitude', 70171),
#  ('pickup_latitude', 71729)]
